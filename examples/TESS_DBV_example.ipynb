# %% [markdown]
# This first example of the basic usage of the Pyriod package will be demonstrated at the [TASC5/KASC12 workshop](https://web.mit.edu/tasc5/) in Boston 22-26 July 2019.  It shows how to reproduce the frequency analysis of a pulsating helium-atmosphere white dwarf presented in Bell et al. (A&A, submitted)

# %%
# %matplotlib notebook
import lightkurve as lk
from Pyriod import Pyriod

# %%
lc = lk.search_lightcurvefile('257459955').download().get_lightcurve("PDCSAP_FLUX").flatten(2161).remove_outliers(5)
# Out:
# Warning: 31% (6168/19692) of the cadences will be ignored due to the quality mask (quality_bitmask=175).

# %%
pyriod = Pyriod(lc)

# %%
pyriod.TimeSeries()
# Out:
# Dropdown(description=u'Time Series to Display:', options=('Original', 'Residuals'), value='Original')
# <img src="data:image/png;base64,..." width="600">

# %%
pyriod.Periodogram()
# Out:
# RHJvcGRvd24oZGVzY3JpcHRpb249dSdQZXJpb2RvZ3JhbSB0byBEaXNwbGF5OicsIG9wdGlvbnM9KCdPcmlnaW5hbCcsICdSZXNpZHVhbHMnLCAnTW9kZWwnLCAnV2luZG93JyksIHZhbHVlPSfigKY=
# QnV0dG9uKGRlc2NyaXB0aW9uPXUnUmVjYWxjdWxhdGUnLCBkaXNhYmxlZD1UcnVlLCBpY29uPXUncmVmcmVzaCcsIHN0eWxlPUJ1dHRvblN0eWxlKCksIHRvb2x0aXA9dSdDbGljayB0byByZWPigKY=
# Text(value=u'134.8888310479736', description=u'Frequency:', placeholder=u'')
# FloatText(value=0.022004679885875705, description=u'Amplitude:')
# QnV0dG9uKGJ1dHRvbl9zdHlsZT11J3N1Y2Nlc3MnLCBkZXNjcmlwdGlvbj11J0FkZCB0byBzb2x1dGlvbicsIGljb249dSdwbHVzJywgc3R5bGU9QnV0dG9uU3R5bGUoKSwgdG9vbHRpcD11J0PigKY=
# Checkbox(value=True, description=u'Snap clicks to peaks?')
# Checkbox(value=False, description=u'Show frequencies in period solution?')
# <img src="data:image/png;base64,..." width="600">

# %%
pyriod.Signals()
# Out:
# QnV0dG9uKGRlc2NyaXB0aW9uPXUnUmVmaW5lIGZpdCcsIGljb249dSdyZWZyZXNoJywgc3R5bGU9QnV0dG9uU3R5bGUoKSwgdG9vbHRpcD11J1JlZmluZSBmaXQgb2Ygc2lnbmFscyB0byB0aW3igKY=
# UWdyaWRXaWRnZXQoZ3JpZF9vcHRpb25zPXsnZGVmYXVsdENvbHVtbldpZHRoJzogMTUwLCAnaGlnaGxpZ2h0U2VsZWN0ZWRSb3cnOiBUcnVlLCAnZW5hYmxlVGV4dFNlbGVjdGlvbk9uQ2VsbHPigKY=

# %%
pyriod.Log()
# Out:
# 2019-07-14 22:12:40,180 - INFO - Pyriod object initialized.
# 2019-07-14 22:12:43,182 - INFO - Signal f0 added to model with frequency 134.888831048 and amplitude 0.0220046798859.
# 2019-07-14 22:12:46,570 - INFO - Signal f1 added to model with frequency 144.590010512 and amplitude 0.0124807626068.
# 2019-07-14 22:12:48,777 - INFO - Signal f2 added to model with frequency 127.353886469 and amplitude 0.0131954012168.
# 2019-07-14 22:12:51,103 - INFO - Signal f3 added to model with frequency 177.952001539 and amplitude 0.00414624650174.
# 2019-07-14 22:12:53,237 - INFO - Signal f4 added to model with frequency 262.242717517 and amplitude 0.00564994977839.
# 2019-07-14 22:12:55,404 - INFO - Signal f5 added to model with frequency 254.702838462 and amplitude 0.00203334838963.
# 2019-07-14 22:12:57,644 - INFO - Signal f6 added to model with frequency 279.473907085 and amplitude 0.0051455881465.
# 2019-07-14 22:13:00,457 - INFO - Signal f7 added to model with frequency 269.777662096 and amplitude 0.00446046830439.
# 2019-07-14 22:13:08,043 - INFO - Signal f8 added to model with frequency 115.313765465 and amplitude 0.00283794636299.
# 2019-07-14 22:13:14,456 - INFO - Fit refined.
# 2019-07-14 22:13:15,585 - INFO - Fit refined.
# 2019-07-14 22:13:16,539 - INFO - Fit refined.
# 2019-07-14 22:13:17,399 - INFO - Fit refined.
# 2019-07-14 22:13:18,187 - INFO - Fit refined.
# 2019-07-14 22:13:18,937 - INFO - Fit refined.
# 2019-07-14 22:13:19,786 - INFO - Fit refined.
# 2019-07-14 22:13:44,954 - INFO - Signal f9 added to model with frequency 99.7701666286 and amplitude 0.00206255645152.
# 2019-07-14 22:13:52,131 - INFO - Signal f10 added to model with frequency 271.938962506 and amplitude 0.00205113081598.
# 2019-07-14 22:13:59,862 - INFO - Signal f11 added to model with frequency 142.897485306 and amplitude 0.00373507703079.
# 2019-07-14 22:14:02,573 - INFO - Signal f12 added to model with frequency 154.937606309 and amplitude 0.00356220690003.
# 2019-07-14 22:14:09,162 - INFO - Signal f13 added to model with frequency 9.70611394028 and amplitude 0.00259258193419.
# 2019-07-14 22:14:10,842 - INFO - Signal f14 added to model with frequency 7.53494457895 and amplitude 0.00228219255925.
# 2019-07-14 22:14:15,136 - INFO - Signal f15 added to model with frequency 352.020570608 and amplitude 0.0020096090844.
# 2019-07-14 22:14:23,333 - INFO - Fit refined.
# 2019-07-14 22:14:27,497 - INFO - Fit refined.
